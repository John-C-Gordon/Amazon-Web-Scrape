# %%
# import sys
# !{sys.executable} -m pip install selenium

# %%
from selenium import webdriver

# %%
import sys
# !{sys.executable} -m pip install requests_html

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
URL = 'https://www.amazon.com/Casio-Celviano-Digital-Cabinet-Piano/dp/B07BV3DYPD'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}



page = requests.get(URL, headers=headers)

soup1 = bs(page.content, "html.parser")

soup2 = bs(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find('span', class_ = 'a-offscreen').get_text()

soup1
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
title = title.strip()

print(title)
print(price)
# Out:
# Casio AP-470 Celviano Digital Piano (Black)
#
#                        $1,699.00

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2022-09-04

# %%
import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\alexf\AmazonWebScraperDataset.csv')

print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/johncroxtongordon/WORKING Celviano Web Scrape.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv(r'C:\Users\alexf\AmazonWebScraperDataset.csv')
#       <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> print(df)
#
# File ~/john/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
# ...

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 14.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.7/504.7 KB 10.4 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 19.0 MB/s eta 0:00:0000:0100:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/johncroxtongordon/john/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# import pandas as pd

# %%
# print(title)
# # print(price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(title)
#       2 print(price)
#
# NameError: name 'title' is not defined

# %%
price.strip()[1:]
# Out:
# '1,699.00'

# %%
price = price.strip()[1:]
title = title.strip()

print(title)
print(price)
# Out:
# Casio AP-470 Celviano Digital Piano (Black)
# 1,699.00

# %%
import csv

header = ['Product', 'Price', 'Date']

data = [title, price, today]

with open('CelvianoScraperDataset.csv', 'w', newline='', encoding='UTF8')as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv('CelvianoScraperDataset.csv')

print(df)
# Out:
#                                        Product     Price        Date
# 0  Casio AP-470 Celviano Digital Piano (Black)  1,699.00  2022-09-04

# %%
with open('CelvianoScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com/Casio-Celviano-Digital-Cabinet-Piano/dp/B07BV3DYPD'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = bs(page.content, "html.parser")

    soup2 = bs(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find('span', class_ = 'a-offscreen').get_text()
    
    price = price.strip()[1:]
    title = title.strip()
    
    import datetime
    today = datetime.date.today()
    
    import csv
    
    header = ['Product', 'Price', 'Date']

    data = [title, price, today]
    
    with open('CelvianoScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price
    time.sleep(864000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/johncroxtongordon/WORKING Celviano Web Scrape.ipynb Cell 20 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> while(True):
#       <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>     check_price
# ----> <a href='vscode-notebook-cell:/Users/johncroxtongordon/WORKING%20Celviano%20Web%20Scrape.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     time.sleep(864000)
#
# NameError: name 'time' is not defined

# %%
import smtplib
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('cougarbeatrice@gmail.com','offabean10')
    
    subject = "Casio Celviano Grand Hybrid for less than $1500"
    body = "Cougar, This is the moment we have been waiting for. Now is your chance to pick up the grand hybrid of your dreams. Don't fuck it up! Link here: https://www.amazon.com/Casio-Celviano-Digital-Cabinet-Piano/dp/B07BV3DYPD"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'cougarbeatrice@gmail.com',
        msg
     
    )
